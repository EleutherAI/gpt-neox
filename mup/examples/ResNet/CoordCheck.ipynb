# %%
from main import coord_check
from itertools import product
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
import os
os.makedirs('coord_checks', exist_ok=True)

# %%
for mup, (lr, optimizer) in product([False, True], [(0.01, 'adam'), (0.01, 'sgd')]):
  coord_check(mup=mup,
              lr=lr, optimizer=optimizer, nsteps=3, arch='resnet18',
              base_shapes='resnet18.bsh', nseeds=1, plotdir='coord_checks', legend=False)
  plt.show()
# Out:
# Files already downloaded and verified
# 100%|█████████████████████████████████████████████| 4/4 [00:04<00:00,  1.02s/it]
# coord check plot saved to coord_checks/sp_resnet18_adam_coord.png
# Files already downloaded and verified
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.51it/s]
# coord check plot saved to coord_checks/sp_resnet18_sgd_coord.png
# Files already downloaded and verified
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  2.91it/s]
# coord check plot saved to coord_checks/μp_resnet18_adam_coord.png
# Files already downloaded and verified
# 100%|█████████████████████████████████████████████| 4/4 [00:01<00:00,  3.47it/s]
# coord check plot saved to coord_checks/μp_resnet18_sgd_coord.png
